# %%
import os
import pickle

# %%
data_dir = '../../anet_videos/frames/'

frames = [f for f in os.listdir(data_dir)]
print len(frames)
# Out:
# 18590

# %%
with open('video_list', 'w') as outfile:
    pickle.dump(frames, outfile)

# %%
with open('video_list', 'r') as f:
    l = pickle.load(f)
    print l
# Out:
# ['p1_6T9d4ZuY', 'EJiyr-6l3ps', 'DRK5oUhjwTg', 'uJAL31wAD2A', 'U_4goX5w_1c', 'zkLld95_bhg', 'KXMZHfCwTO0', 'A-FI48u86dQ', 's80tsQgUczA', 'QxPi0RyYnqY', 'Jy8JurvYlH4', 'lnOZvhRNC8E', 'OzAqwPQ-APY', '_zAfwnDt4VE', 'jimvzigX1ak', 'Zt9nALIsHPc', 'HVhLOYGU9E4', 'Gkv5ibx0tYw', 'UAgb3FEjBN8', '0ecdkXfxQUA', 'paY7wXmzcTQ', 'b1QkoG9hxk8', 'adLA8Fu4Wlc', 'yKbRi1SZilA', 'sNnNDCx6RRA', 'zxOcSuLSrU4', 'r9xmgB116dE', 'w9NZm9-cxbg', 'gl2eHq4nRus', 'Z-kXPcLsxBg', 'yIIDIQDKVhI', 'Lliy0OcwzUE', 'dcclQadR-L0', '1fmaEo3wzxg', '76hO-Xc1VzA', 'Erje-PwY9hE', 'jDfTrTtPs5s', 'CKczltkk_7g', 'cf6y94fjhHw', 'ItukN-TWrJM', '-YwrMtiqHKg', 'b8pCuIPzb3o', 'w24Pub_hNSw', 'K6QunmuTZOQ', 'aQQr1ad0v1I', 'Z47Ig2AqKfg', 'DjY-7jEpxZ0', 'pDuceHUHFt0', '5T_P4x0q0VM', 'gzs6VcYc0OI', 'rx_WRuQ-X14', 'QRn9v8F8Nn0', 'IDr50VT8BK8', 'K9qWnvl8A1Q', 'nDGhaYCgRiI', 'op58Lalekrk', 'qGLRri_c6n8', 'xgb-qIgWHw0', '7oBW5W6Fdok', 'm5YvKrjGtPM', 'HkbOI7gEtKk', 'wvQS6xeOhOI', 'mNM-JUC7ZEA', 'uowNtTu74nA', 'cY0E0B1b3KA', 'LygR7ds26JY', 'H9PaZi
# ...
